# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns# for visualization

path='./Pokemon.csv'
data=pd.read_csv(path)
print(data.shape)
data.drop('#',axis=1,inplace=True)
display(data.head())
display(data.tail())
# Out:
# (800, 13)
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#                     Name   Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 795              Diancie     Rock  Fairy    600  50     100      150      100
# 796  DiancieMega Diancie     Rock  Fairy    700  50     160      110      160
# ...

# %%
names=data['Name'].unique()
print(names)
# Out:
# ['Bulbasaur' 'Ivysaur' 'Venusaur' 'VenusaurMega Venusaur' 'Charmander'
#  'Charmeleon' 'Charizard' 'CharizardMega Charizard X'
#  'CharizardMega Charizard Y' 'Squirtle' 'Wartortle' 'Blastoise'
#  'BlastoiseMega Blastoise' 'Caterpie' 'Metapod' 'Butterfree' 'Weedle'
#  'Kakuna' 'Beedrill' 'BeedrillMega Beedrill' 'Pidgey' 'Pidgeotto'
#  'Pidgeot' 'PidgeotMega Pidgeot' 'Rattata' 'Raticate' 'Spearow' 'Fearow'
#  'Ekans' 'Arbok' 'Pikachu' 'Raichu' 'Sandshrew' 'Sandslash' 'Nidoran♀'
#  'Nidorina' 'Nidoqueen' 'Nidoran♂' 'Nidorino' 'Nidoking' 'Clefairy'
#  'Clefable' 'Vulpix' 'Ninetales' 'Jigglypuff' 'Wigglytuff' 'Zubat'
#  'Golbat' 'Oddish' 'Gloom' 'Vileplume' 'Paras' 'Parasect' 'Venonat'
#  'Venomoth' 'Diglett' 'Dugtrio' 'Meowth' 'Persian' 'Psyduck' 'Golduck'
#  'Mankey' 'Primeape' 'Growlithe' 'Arcanine' 'Poliwag' 'Poliwhirl'
#  'Poliwrath' 'Abra' 'Kadabra' 'Alakazam' 'AlakazamMega Alakazam' 'Machop'
#  'Machoke' 'Machamp' 'Bellsprout' 'Weepinbell' 'Victreebel' 'Tentacool'
# ...

# %%
ind=data[data['Name']== 'Venusaur'].shape[0]
print(ind)
# Out:
# 1

# %%
data.describe().astype(int)
# Out:
#        Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# count    800  800     800      800      800      800    800         800
# mean     435   69      79       73       72       71     68           3
# std      119   25      32       31       32       27     29           1
# min      180    1       5        5       10       20      5           1
# 25%      330   50      55       50       49       50     45           2
# 50%      450   65      75       70       65       70     65           3
# 75%      515   80     100       90       95       90     90           5
# max      780  255     190      230      194      230    180           6

# %%
sns.distplot(data['Attack'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Attack', ylabel='Density'>

# %%
sns.boxplot(data['Attack'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Attack'>

# %%
sns.displot(data['Attack'])

# %%
sns.histplot(data['Attack'])
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Count'>

# %%
new_data=data.drop(['Name','Type 1','Type 2','Legendary','Generation','Total'],axis=1)
sns.boxplot(data=new_data)
# Out:
# <AxesSubplot:>

# %%
# print the name of the pokemon having HP >220
# print the name of the pokemon having HP <10

nData=data[(data['HP']>220)]

print(nData['Name'])


nData1=data[(data['HP']<10)]

print(nData1['Name'])
# Out:
# 121    Chansey
# 261    Blissey
# Name: Name, dtype: object
# 316    Shedinja
# Name: Name, dtype: object

# %%
nD = data[data['HP']>=220]

print(nD['Name'])
display(nD[['Name','HP']])
print(type(nD))
# print the name of the pokemon having HP <10
nD = data[data['HP']<10]

nD[['Name','HP']]
# Out:
# 121    Chansey
# 261    Blissey
# Name: Name, dtype: object
#         Name   HP
# 121  Chansey  250
# 261  Blissey  255
# <class 'pandas.core.frame.DataFrame'>
#          Name  HP
# 316  Shedinja   1

# %%
data
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
plt.figure(2,figsize=(15,10))
sns.countplot(data['Type 1'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type 1', ylabel='count'>

# %%
plt.figure(3,figsize=(15,10))
sns.countplot(data['Type 2'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type 2', ylabel='count'>

# %%
plt.figure(4,figsize=(10,5))
sns.countplot(y=data['Generation'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Generation'>

# %%
plt.figure(5,figsize=(10,5))
sns.countplot(data['Legendary'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Legendary', ylabel='count'>

# %%
plt.figure(5,figsize=(10,5))
sns.countplot(data['Generation'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Generation', ylabel='count'>

# %% [markdown]
# 1. Visualize the attack histogram of all the generations of the pokemon
# 2. Visualize defense vs attack of fire and water type pokemon
# 3. Find the strongest pokemon by type
# 4. Distribution of all type of pokemon in the pie chart
# 5. Comparative analysis of the number of pokemon by type and its generation

# %%
# 1. Visualize the attack histogram of all the generations of the pokemon
plt.figure(7,figsize=(15,5))
sns.histplot(x=data['Generation'],y=data['Attack'],hue=data['Type 1'])
# Out:
# <AxesSubplot:xlabel='Generation', ylabel='Attack'>

# %%
#2. Visualize defense vs attack of fire and water type pokemon
nData=data[(data['Type 2']=='Grass') |(data['Type 2']=='Fire')]
#display(nData)
ntype=nData['Type 2']
#print(ntype)
sns.scatterplot(x=data['Defense'],y=data['Attack'],hue=ntype)
# Out:
# <AxesSubplot:xlabel='Defense', ylabel='Attack'>

# %%
#3. Find the strongest pokemon by type
mx=data['HP'].max()
nData=data[data['HP']==mx]
name=nData['Name'].unique()
pokemon=nData['Type 1'].unique()
print("The highest HP is :",mx)
print("The Strongest pokemon is: ",name," and the type is ",pokemon)
# Out:
# The highest HP is : 255
# The Strongest pokemon is:  ['Blissey']  and the type is  ['Normal']

# %%
#4. Distribution of all type of pokemon in the pie chart
import numpy as np

type1=data['Type 1'].unique()
#print(type1)
result=np.zeros([1,len(type1)])

for i in range(len(type1)):
    result[0,i]=data[(data['Type 1']==type1[i])].shape[0]
#print(result)
nDataFrame=(pd.DataFrame(result,index=['Type 1'],columns=type1)).T
#display(nDataFrame)
nDataFrame.plot(title="Type 1 Pokemon",kind='pie',subplots=True,figsize=(10,8))



type2=data['Type 2'].unique()
#print(type2)
result1=np.zeros([1,len(type2)])
for j in range(len(pokemontype2)):
    result1[0,j]=data[(data['Type 2']==type2[j])].shape[0]
#print(result1)
nDataFrame1=(pd.DataFrame(result1,index=['Type 2'],columns=type2)).T
#display(nDataFrame1)

nDataFrame1.plot(title="Type 2 Pokemon",kind='pie',subplots=True,figsize=(10,8))
# Out:
# array([<AxesSubplot:ylabel='Type 2'>], dtype=object)

# %%
#5. Comparative analysis of the number of pokemon by type and its generation
plt.figure(5,figsize=(15,10))
pokemon=data['Name']
sns.countplot(x=data['Type 1'],hue=data['Generation'])
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='count'>
